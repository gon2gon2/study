# %%
cols = {
'타임스탬프' : 'time',
'귀하의 이수학기 (2021 - 1학기 기준)' : 'semester',
'귀하의 주전공 학과는?' : 'major',
'복수전공 or 부전공 or 연계전공 여부' : 'otherMajoryn',
'복수전공 or 부전공 or 연계전공 학과는?' : 'otherMajor',
'귀하께서는 본인의 MBTI를 알고 있습니까?' : 'MBTIyn',
'내향형(I)인가요 외향형(E)인가요?' : 'MBTI_IE',
'감각형(S)인가요 직관형(N)인가요?' : 'MBTI_SN',
'사고형(T)인가요 감정형(F)인가요?' : 'MBTI_TF',
'판단형(J)인가요 인식형(P)인가요?' : 'MBTI_JP',
'팀플할 때 팀장 하는 스타일' : 'leader',
'친목 모임에서 선호하는 인원 수' : 'gathering',
'당신의 카톡 스타일은?' : 'chat_style',
'고양이 VS 강아지' : 'animal',
'한식 vs 양식 vs 일식 vs 중식' : 'food',
'여름 vs 겨울' : 'season',
'버스 vs 지하철' : 'transportation',
'치킨 vs 피자' : 'fastfood_choice', #?
'귀하가 사용하는 핸드폰의 브랜드' : 'cellphone',
'좋아하는 색' : 'color',
'본인은 아침형 인간 vs 올빼미형 인간' : 'lifeStyle',
'주로 몇 시에 기상하시나요? ' : 'getup',
'일주일 평균 식비는?' : 'Engel',
'최근 한달 간 책 읽은 횟수' : 'book',
'주로 공부 잘 되는 시간' : 'focus_time',
'시험공부 스타일' : 'studystyle',
'일주일에 운동, 체력단련에 투자하는 시간' : 'workout',
'QR 체크인 방식' : 'QR',
'알바 여부 (현재)' : 'partTime',
'AI를 공부한 기간' : 'AIstudy',
'SAI 노션 일주일 평균 방문횟수?' : 'notion',
'SAI 채널 구독여부' : 'subscribe',
'귀하께서 가장 익숙한 프로그래밍 언어는 무엇입니까?' : 'language',
'귀하의 프로젝트 진행횟수 (대학 재학 중)' : 'projects',
'둘다 붙었다면 카카오 VS 네이버' : 'kakao_naver',
'귀하는 현재 목(어깨)에 거북목이 있으십니까?' : 'turtle',
'노트북에 스티커를 붙이는 편인가요?' : 'sticker',
'사용하는 노트북의 브랜드' : 'laptop'
}

# %% [markdown]
# 1. MBTI E 성향이면 Engel이 높을까?
# 2. MBTI E 성향이면 모임 인원 선호도의 상관성은?
# 3. MBTI J와 벼락치기의 상관관계는?
# 4. 거북목과 AI공부한 기간+ 프로젝트 횟수
# 5. SAI채널 구독과 Notion 방문횟수
# 6. 색과 카카오_네이버의 관계?
# 7. 이수학기 와 프로젝트 진행횟수?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pd. set_option("display.max_columns", None)

# %%
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/NGULIM.TTF"
# font_path = "‪C:/Users/fizz5/AppData/Local/Microsoft/Windows/Fonts/a옛날목욕탕L.ttf"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

# %%
df = pd.read_csv('./pj/sai_data.csv', encoding='cp949')
df = df.drop("Unnamed: 0",1)

# %%
df
# Out:
#           semester  semester_int       major           otherMajor MBTI_IE  \
# 0              7학기             7      컴퓨터공학과                 해당없음       E
# 1      8학기 (또는 졸업)             8    호텔관광경영학과  스마트투어리즘 매니지먼트 소프트웨어       E
# 2              7학기             7   전자정보통신공학과                 해당없음       I
# 3              6학기             6        교육학과      글로벌미디어소프트웨어연계전공       I
# 4              3학기             3   데이터사이언스학과            비즈니스애널리틱스       E
# 5              5학기             5      컴퓨터공학과                 해당없음       E
# 6              7학기             7      응용통계학과                 해당없음       I
# 7              3학기             3    스마트기기공학과                 해당없음       I
# 8              7학기             7      컴퓨터공학과                 해당없음       E
# 9           1학기 이하             1      컴퓨터공학과                 해당없음       I
# 10             7학기             7     소프트웨어학과               정보보호학과       E
# 11             6학기             6      컴퓨터공학과                 해당없음       E
# 12             4학기             4      컴퓨터공학과                 해당없음       I
# 13             7학기             7        교육학과                 해당없음       I
# 14             3학기             3     지능기전공학부                 해당없음       I
# 15  8학기 이상 (또는 졸업)             8      컴퓨터공학과                 해당없음       E
# 16             3학기             3     지능기전공학부                 해당없음       E
# 17             6학기             6    스마트기기공학과                 해당없음       I
# 18          1학기 이하             1      인공지능학과                 해당없음       E
# 19             3학기             3        경영학과                 해당없음       I
# 20             5학기             5     소프트웨어학과                 해당없음       I
# 21             5학기             5      컴퓨터공학과                 해당없음       I
# 22             5학기             5      수학통계학부               컴퓨터공학과       E
# 23             3학기             3   전자정보통신공학과                 해당없음       I
# 24  8학기 이상 (또는 졸업)             8        경영학과             디지털콘텐츠학과       E
# 25             5학기             5     소프트웨어학과                 해당없음       I
# 26             5학기             5     소프트웨어학과                 해당없음       I
# 27             3학기             3      응용통계학과                 해당없음       I
# 28             4학기             4      컴퓨터공학과                 해당없음       E
# 29             5학기             5    무인이동체공학과                 해당없음       E
# 30             3학기             3  바이오산업자원공학과                 해당없음       E
# 31             5학기             5   데이터사이언스학과                 해당없음       E
# 32             5학기             5      컴퓨터공학과                 해당없음       I
# 33  8학기 이상 (또는 졸업)             8      컴퓨터공학과                 해당없음       E
# 34             5학기             5      정보보호학과                 해당없음       I
# 35             7학기             7     소프트웨어학과                 해당없음       I
# 36             4학기             4   전자정보통신공학과                 해당없음       E
# 37  8학기 이상 (또는 졸업)             8     지능기전공학부                 해당없음       E
# 38             5학기             5     소프트웨어학과                 해당없음       E
# 39          1학기 이하             1      컴퓨터공학과                 해당없음       I
# 40  8학기 이상 (또는 졸업)             8    무인이동체공학과                 해당없음       E
# 41             3학기             3    스마트기기공학과                 해당없음       I
# 42             7학기             7      컴퓨터공학과                 해당없음       I
# 43             7학기             7      컴퓨터공학과                 해당없음       I
# 44             7학기             7      컴퓨터공학과                 해당없음       I
# 45             7학기             7      컴퓨터공학과                 해당없음       I
# 46             7학기             7      컴퓨터공학과                 해당없음       I
# 47             5학기             5   전자정보통신공학과                 해당없음       E
# 48             5학기             5   전자정보통신공학과                 해당없음       E
# 49             5학기             5   전자정보통신공학과                 해당없음       E
# 50             5학기             5   전자정보통신공학과                 해당없음       E
#
#    MBTI_SN MBTI_TF MBTI_JP      leader gathering      chat_style animal food  \
# 0        N       T       J     절대 안한다.     4명 이상   선톡(내가 먼저 보낸다)    고양이   한식
# 1        S       T       J  없으면 내가 한다.      3~4명  오는톡(오면 답장만 한다)    고양이   한식
# 2        N       T       J  없으면 내가 한다.      3~4명   선톡(내가 먼저 보낸다)    고양이   양식
# 3        S       F       J  시키면 하긴 한다.      3~4명  오는톡(오면 답장만 한다)    고양이   한식
# 4        S       T       J     나서서 한다.    10명 이상   선톡(내가 먼저 보낸다)    고양이   한식
# 5        N       T       J  시키면 하긴 한다.     4명 이상  오는톡(오면 답장만 한다)    강아지   양식
# 6        N       T       J  없으면 내가 한다.      3~4명  오는톡(오면 답장만 한다)    강아지   한식
# 7        S       F       J  없으면 내가 한다.      3~4명  오는톡(오면 답장만 한다)    고양이   일식
# 8        N       T       J     나서서 한다.      3~4명   선톡(내가 먼저 보낸다)    강아지   양식
# 9        S       T       J  시키면 하긴 한다.      3~4명  오는톡(오면 답장만 한다)    고양이   한식
# 10       N       F       P  없으면 내가 한다.      3~4명   선톡(내가 먼저 보낸다)    강아지   한식
# 11       N       T       P     나서서 한다.      3~4명   선톡(내가 먼저 보낸다)    강아지   양식
# 12       S       F       J  없으면 내가 한다.      3~4명   선톡(내가 먼저 보낸다)    고양이   한식
# 13       N       T       J  없으면 내가 한다.      3~4명  오는톡(오면 답장만 한다)    고양이   한식
# 14       S       F       J  시키면 하긴 한다.      3~4명  오는톡(오면 답장만 한다)    고양이   양식
# 15       N       T       J  없으면 내가 한다.      3~4명  오는톡(오면 답장만 한다)    고양이   일식
# 16       S       T       P  없으면 내가 한다.      3~4명  오는톡(오면 답장만 한다)    강아지   양식
# 17       N       F       P  시키면 하긴 한다.      3~4명  오는톡(오면 답장만 한다)    고양이   일식
# 18       N       F       P  없으면 내가 한다.      3~4명  오는톡(오면 답장만 한다)    고양이   한식
# 19       S       F       J  시키면 하긴 한다.      3~4명   선톡(내가 먼저 보낸다)    강아지   양식
# 20       S       F       P  시키면 하긴 한다.      1~2명  오는톡(오면 답장만 한다)    강아지   한식
# 21       N       F       P  없으면 내가 한다.      3~4명   선톡(내가 먼저 보낸다)    고양이   한식
# 22       S       F       P  없으면 내가 한다.      3~4명  오는톡(오면 답장만 한다)    강아지   한식
# 23       N       F       P  없으면 내가 한다.      3~4명  오는톡(오면 답장만 한다)    강아지   양식
# 24       S       T       J     나서서 한다.      3~4명   선톡(내가 먼저 보낸다)    고양이   한식
# 25       S       F       J  시키면 하긴 한다.      3~4명  오는톡(오면 답장만 한다)    강아지   일식
# 26       S       T       P  없으면 내가 한다.      3~4명  오는톡(오면 답장만 한다)    강아지   일식
# 27       S       T       J     절대 안한다.      1~2명  오는톡(오면 답장만 한다)    강아지   양식
# 28       N       T       P     나서서 한다.     4명 이상  오는톡(오면 답장만 한다)    강아지   한식
# 29       S       F       J  없으면 내가 한다.     4명 이상   선톡(내가 먼저 보낸다)    강아지   양식
# 30       N       F       J  없으면 내가 한다.      3~4명  오는톡(오면 답장만 한다)    고양이   일식
# 31       N       F       J  없으면 내가 한다.      3~4명   선톡(내가 먼저 보낸다)    강아지   한식
# 32       N       F       P  시키면 하긴 한다.      1~2명  오는톡(오면 답장만 한다)    강아지   양식
# 33       S       T       J  없으면 내가 한다.     4명 이상   선톡(내가 먼저 보낸다)    강아지   한식
# 34       N       T       P  시키면 하긴 한다.      3~4명   선톡(내가 먼저 보낸다)    고양이   한식
# 35       S       F       P  없으면 내가 한다.      3~4명  오는톡(오면 답장만 한다)    강아지   일식
# 36       N       T       P     나서서 한다.     4명 이상  오는톡(오면 답장만 한다)    고양이   한식
# 37       N       T       P  시키면 하긴 한다.      3~4명  오는톡(오면 답장만 한다)    고양이   양식
# 38       N       T       J     나서서 한다.      3~4명   선톡(내가 먼저 보낸다)    고양이   일식
# 39       S       T       P  없으면 내가 한다.     4명 이상   선톡(내가 먼저 보낸다)    고양이   일식
# 40       N       T       J  없으면 내가 한다.      3~4명  오는톡(오면 답장만 한다)    강아지   한식
# 41       S       F       P  시키면 하긴 한다.      3~4명  오는톡(오면 답장만 한다)    강아지   한식
# 42       N       F       P  없으면 내가 한다.      3~4명  오는톡(오면 답장만 한다)    강아지   일식
# 43       N       F       P  없으면 내가 한다.      3~4명  오는톡(오면 답장만 한다)    강아지   일식
# 44       N       F       P  없으면 내가 한다.      3~4명  오는톡(오면 답장만 한다)    강아지   일식
# 45       N       F       P  없으면 내가 한다.      3~4명  오는톡(오면 답장만 한다)    강아지   일식
# 46       N       F       P  없으면 내가 한다.      3~4명  오는톡(오면 답장만 한다)    강아지   일식
# 47       S       F       J  없으면 내가 한다.      3~4명   선톡(내가 먼저 보낸다)    강아지   한식
# 48       S       F       J  없으면 내가 한다.      3~4명   선톡(내가 먼저 보낸다)    강아지   한식
# 49       S       F       J  없으면 내가 한다.      3~4명   선톡(내가 먼저 보낸다)    강아지   한식
# 50       S       F       J  없으면 내가 한다.      3~4명   선톡(내가 먼저 보낸다)    강아지   한식
#
#    season transportation fastfood_choice cellphone color lifeStyle  getup  \
# 0      여름            지하철              치킨        애플    빨강    아침형 인간      6
# 1      겨울             버스              치킨        삼성    노랑    아침형 인간      8
# 2      겨울            지하철              피자        삼성    빨강   올빼미형 인간     13
# 3      겨울            지하철              피자        삼성    검정   올빼미형 인간     11
# 4      겨울            지하철              피자        삼성    검정   올빼미형 인간     10
# 5      겨울             버스              치킨        삼성    보라   올빼미형 인간      9
# 6      여름            지하철              치킨        삼성    파랑   올빼미형 인간      9
# 7      겨울            지하철              치킨        삼성    검정   올빼미형 인간      9
# 8      여름             버스              치킨        애플    주황   올빼미형 인간      7
# 9      겨울            지하철              치킨        삼성    검정   올빼미형 인간     10
# 10     여름            지하철              치킨        애플    하늘    아침형 인간      9
# 11     겨울             버스              치킨        삼성    초록   올빼미형 인간     11
# 12     겨울             버스              치킨        애플    검정    아침형 인간      8
# 13     겨울            지하철              치킨        애플    파랑   올빼미형 인간     10
# 14     겨울             버스              치킨        애플    분홍   올빼미형 인간     12
# 15     여름             버스              피자        삼성    파랑   올빼미형 인간      8
# 16     겨울             버스              피자        애플    파랑   올빼미형 인간     12
# 17     겨울            지하철              치킨        LG    하늘    아침형 인간      8
# 18     겨울            지하철              치킨        애플    분홍   올빼미형 인간     10
# 19     겨울            지하철              피자        애플    하양   올빼미형 인간     12
# 20     겨울             버스              피자        애플    파랑   올빼미형 인간     10
# 21     겨울            지하철              치킨        삼성    하늘   올빼미형 인간     12
# 22     여름             버스              치킨        애플    하양    아침형 인간      9
# 23     겨울            지하철              치킨        애플    검정   올빼미형 인간     15
# 24     겨울             버스              피자        애플    파랑   올빼미형 인간      8
# 25     겨울             버스              피자        애플    초록   올빼미형 인간      9
# 26     겨울            지하철              치킨        삼성  로즈골드    아침형 인간      6
# 27     겨울             버스              피자        애플    파랑   올빼미형 인간      9
# 28     여름             버스              치킨        삼성    하양   올빼미형 인간      7
# 29     겨울            지하철              치킨        애플    하양    아침형 인간     10
# 30     겨울            지하철              치킨        애플    보라   올빼미형 인간      9
# 31     겨울             버스              피자        애플    하양    아침형 인간      9
# 32     겨울             버스              치킨        애플    하양   올빼미형 인간     10
# 33     겨울            지하철              피자        삼성    초록   올빼미형 인간     11
# 34     여름            지하철              피자        삼성    파랑   올빼미형 인간     11
# 35     겨울            지하철              치킨        애플    노랑   올빼미형 인간     15
# 36     겨울             버스              피자        삼성    검정   올빼미형 인간     11
# 37     겨울             버스              치킨        애플    검정   올빼미형 인간      9
# 38     여름             버스              피자        애플    노랑   올빼미형 인간     12
# 39     겨울            지하철              치킨        애플    하양   올빼미형 인간     12
# 40     겨울             버스              치킨        애플    파랑    아침형 인간      5
# 41     겨울            지하철              치킨        애플    파랑   올빼미형 인간     12
# 42     겨울             버스              피자        애플    파랑   올빼미형 인간     10
# 43     겨울             버스              피자        애플    연두   올빼미형 인간     10
# 44     겨울             버스              피자        애플    초록   올빼미형 인간     10
# 45     겨울             버스              피자        애플    보라   올빼미형 인간     10
# 46     겨울             버스              피자        애플    살구   올빼미형 인간     10
# 47     여름             버스              피자        LG    검정   올빼미형 인간     11
# 48     여름             버스              피자        LG    초록   올빼미형 인간     11
# 49     여름             버스              피자        LG    노랑   올빼미형 인간     11
# 50     여름             버스              피자        LG    주황   올빼미형 인간     11
#
#      Engel       book focus_time     studystyle  workout    QR partTime  \
# 0   100000       2~4권  낮 (오전~오후)  꾸준히 미리 공부 해놓기     14.0   네이버     안 한다
# 1    50000      1권 이하  밤 (저녁~새벽)           벼락치기      1.0   카카오    하고 있다
# 2    70000       2~4권  밤 (저녁~새벽)  꾸준히 미리 공부 해놓기      6.0   카카오     안 한다
# 3    30000      1권 이하    때때로 다르다           벼락치기      2.0   카카오    하고 있다
# 4    10000  책을 읽지 않는다    때때로 다르다  꾸준히 미리 공부 해놓기      6.0   네이버    하고 있다
# 5   200000       2~4권    때때로 다르다  꾸준히 미리 공부 해놓기      4.0   네이버     안 한다
# 6   180000      1권 이하  낮 (오전~오후)  꾸준히 미리 공부 해놓기     14.0   네이버     안 한다
# 7    70000      1권 이하  밤 (저녁~새벽)  꾸준히 미리 공부 해놓기      1.0   카카오     안 한다
# 8   100000      1권 이하    때때로 다르다  꾸준히 미리 공부 해놓기      7.0    토스     안 한다
# 9    70000  책을 읽지 않는다  밤 (저녁~새벽)           벼락치기      3.0  수기작성     안 한다
# 10  100000      1권 이하    때때로 다르다  꾸준히 미리 공부 해놓기      5.0   카카오    하고 있다
# 11   70000  책을 읽지 않는다  밤 (저녁~새벽)           벼락치기      0.0   카카오     안 한다
# 12   50000      1권 이하    때때로 다르다           벼락치기      5.0   카카오    하고 있다
# 13   70000      1권 이하    때때로 다르다           벼락치기      3.0   카카오     안 한다
# 14   20000      1권 이하  밤 (저녁~새벽)           벼락치기      5.0   카카오    하고 있다
# 15  100000       2~4권    때때로 다르다  꾸준히 미리 공부 해놓기      6.0   카카오     안 한다
# 16   70000      1권 이하  밤 (저녁~새벽)  꾸준히 미리 공부 해놓기      3.0   네이버     안 한다
# 17   70000       2~4권    때때로 다르다           벼락치기      2.0   카카오     안 한다
# 18   90000      1권 이하  밤 (저녁~새벽)           벼락치기      7.0   카카오     안 한다
# 19   40000  책을 읽지 않는다  낮 (오전~오후)           벼락치기      6.0   카카오    하고 있다
# 20   10000       2~4권  밤 (저녁~새벽)           벼락치기      9.0   네이버     안 한다
# 21  150000      1권 이하    때때로 다르다  꾸준히 미리 공부 해놓기      1.0   네이버    하고 있다
# 22   35000      1권 이하  낮 (오전~오후)           벼락치기      4.0   카카오    하고 있다
# 23   50000  책을 읽지 않는다  밤 (저녁~새벽)           벼락치기      0.0   카카오    하고 있다
# 24   70000       2~4권  밤 (저녁~새벽)           벼락치기      5.0   카카오     안 한다
# 25   25000      1권 이하    때때로 다르다  꾸준히 미리 공부 해놓기      0.5   네이버    하고 있다
# 26   50000  책을 읽지 않는다  낮 (오전~오후)  꾸준히 미리 공부 해놓기     10.0   카카오     안 한다
# 27   60000      1권 이하    때때로 다르다  꾸준히 미리 공부 해놓기      2.0   카카오    하고 있다
# 28   50000  책을 읽지 않는다  밤 (저녁~새벽)  꾸준히 미리 공부 해놓기      5.0   네이버     안 한다
# 29   60000      1권 이하    때때로 다르다  꾸준히 미리 공부 해놓기      3.0   카카오     안 한다
# 30   70000       2~4권  밤 (저녁~새벽)           벼락치기     10.0   카카오     안 한다
# 31  100000       2~4권  낮 (오전~오후)  꾸준히 미리 공부 해놓기      3.0   네이버     안 한다
# 32   50000      1권 이하    때때로 다르다           벼락치기      0.0   네이버    하고 있다
# 33   55000  책을 읽지 않는다  밤 (저녁~새벽)           벼락치기      4.5   카카오     안 한다
# 34   80000       2~4권  밤 (저녁~새벽)  꾸준히 미리 공부 해놓기      7.0   카카오     안 한다
# 35   60000  책을 읽지 않는다  밤 (저녁~새벽)           벼락치기      0.0   네이버     안 한다
# 36  100000      1권 이하  밤 (저녁~새벽)           벼락치기      3.0   네이버    하고 있다
# 37   50000      1권 이하    때때로 다르다  꾸준히 미리 공부 해놓기      1.8   카카오     안 한다
# 38   50000      1권 이하  밤 (저녁~새벽)           벼락치기      7.0   카카오    하고 있다
# 39   50000      1권 이하  밤 (저녁~새벽)           벼락치기      0.5   네이버    하고 있다
# 40   63000  책을 읽지 않는다  낮 (오전~오후)  꾸준히 미리 공부 해놓기      0.0   네이버    하고 있다
# 41   90000  책을 읽지 않는다  밤 (저녁~새벽)           벼락치기      9.0   네이버     안 한다
# 42   50000      1권 이하    때때로 다르다           벼락치기      0.5   카카오     안 한다
# 43   50000      1권 이하    때때로 다르다           벼락치기      0.5   카카오     안 한다
# 44   50000      1권 이하    때때로 다르다           벼락치기      0.5   카카오     안 한다
# 45   50000      1권 이하    때때로 다르다           벼락치기      0.5   카카오     안 한다
# 46   50000      1권 이하    때때로 다르다           벼락치기      0.5   카카오     안 한다
# 47   90000  책을 읽지 않는다    때때로 다르다           벼락치기      1.5   카카오    하고 있다
# 48   90000  책을 읽지 않는다    때때로 다르다           벼락치기      1.5   카카오    하고 있다
# 49   90000  책을 읽지 않는다    때때로 다르다           벼락치기      1.5   카카오    하고 있다
# 50   90000  책을 읽지 않는다    때때로 다르다           벼락치기      1.5   카카오    하고 있다
#
#           AIstudy  notion subscribe    language       projects kakao_naver  \
# 0   1년 이상 ~ 2년 미만      10        네!      Python          5번 이상         네이버
# 1   1년 이상 ~ 2년 미만       2        네!      Python  1번 이상 ~ 3번 미만         카카오
# 2   1년 이상 ~ 2년 미만       5        네!      MATLAB          5번 이상         네이버
# 3   1년 이상 ~ 2년 미만       3        네!      Python  1번 이상 ~ 3번 미만         네이버
# 4           1년 미만       3        네!      Python  1번 이상 ~ 3번 미만         카카오
# 5   2년 이상 ~ 3년 미만       5        네!      Python          5번 이상         카카오
# 6   1년 이상 ~ 2년 미만       1        네!      Python  3번 이상 ~ 5번 미만         카카오
# 7           1년 미만       1        네!      Python  1번 이상 ~ 3번 미만         카카오
# 8   1년 이상 ~ 2년 미만       5        네!  JavaScript          5번 이상         네이버
# 9           1년 미만       2        네!      Python             없음         카카오
# 10          1년 미만       3        네!  JavaScript          5번 이상         카카오
# 11          1년 미만       0        네!      Python  1번 이상 ~ 3번 미만         카카오
# 12          1년 미만       2       아니오           C             없음         카카오
# 13          1년 미만       3       아니오      Python  3번 이상 ~ 5번 미만         네이버
# 14          1년 미만       2        네!           C             없음         카카오
# 15          3년 이상       0        네!      Python          5번 이상         카카오
# 16          1년 미만       3        네!           C             없음         카카오
# 17  1년 이상 ~ 2년 미만       0       아니오      Python  3번 이상 ~ 5번 미만         카카오
# 18          1년 미만       1        네!      Python             없음         카카오
# 19  1년 이상 ~ 2년 미만       5        네!      Python             없음         카카오
# 20          1년 미만       1        네!           C  1번 이상 ~ 3번 미만         카카오
# 21          1년 미만       0        네!        JAVA  1번 이상 ~ 3번 미만         카카오
# 22          1년 미만       3        네!           C             없음         카카오
# 23          1년 미만       2        네!      Python  1번 이상 ~ 3번 미만         카카오
# 24  2년 이상 ~ 3년 미만       0        네!      Python  3번 이상 ~ 5번 미만         카카오
# 25          1년 미만       0        네!           C  1번 이상 ~ 3번 미만         카카오
# 26          1년 미만       1        네!      Python  1번 이상 ~ 3번 미만         카카오
# 27          1년 미만       2       아니오      Python             없음         카카오
# 28  1년 이상 ~ 2년 미만       0       아니오      Python  1번 이상 ~ 3번 미만         카카오
# 29  1년 이상 ~ 2년 미만       0        네!         C++  3번 이상 ~ 5번 미만         네이버
# 30  2년 이상 ~ 3년 미만       5        네!        JAVA          5번 이상         카카오
# 31          1년 미만       2        네!      Python          5번 이상         카카오
# 32          1년 미만       0       아니오           C  1번 이상 ~ 3번 미만         카카오
# 33          1년 미만       0        네!  JavaScript             없음         네이버
# 34          1년 미만       3        네!           C          5번 이상         카카오
# 35          1년 미만       0        네!  JavaScript  3번 이상 ~ 5번 미만         카카오
# 36          1년 미만       2        네!           C             없음         카카오
# 37          3년 이상       0        네!      Python          5번 이상         네이버
# 38          1년 미만       2        네!           C  3번 이상 ~ 5번 미만         네이버
# 39          1년 미만       0        네!           C             없음         네이버
# 40  1년 이상 ~ 2년 미만       0        네!      Python          5번 이상         카카오
# 41          1년 미만       0        네!           C             없음         네이버
# 42          1년 미만       0        네!           C  3번 이상 ~ 5번 미만         네이버
# 43          1년 미만       0        네!           C  3번 이상 ~ 5번 미만         네이버
# 44          1년 미만       0        네!           C  3번 이상 ~ 5번 미만         네이버
# 45          1년 미만       0        네!           C  3번 이상 ~ 5번 미만         네이버
# 46          1년 미만       0        네!           C  3번 이상 ~ 5번 미만         네이버
# 47          1년 미만       2        네!      Python             없음         카카오
# 48          1년 미만       2        네!      Python             없음         카카오
# 49          1년 미만       2        네!      Python             없음         카카오
# 50          1년 미만       2        네!      Python             없음         카카오
#
#    turtle sticker  laptop
# 0       네      있다      한성
# 1       네      없다     Msi
# 2     아니오      없다      삼성
# 3     아니오      없다      삼성
# 4     아니오      있다      LG
# 5     아니오      있다      애플
# 6       네      없다    asus
# 7     아니오      있다      LG
# 8     아니오      있다      애플
# 9       네      없다      삼성
# 10      네      있다      애플
# 11      네      있다   기가바이트
# 12      네      없다      애플
# 13      네      없다      LG
# 14      네      있다      삼성
# 15      네      없다  Lenova
# 16      네      없다    asus
# 17      네      없다      애플
# 18      네      없다      애플
# 19    아니오      없다      삼성
# 20      네      있다      삼성
# 21      네      있다      삼성
# 22      네      있다      삼성
# 23    아니오      없다    asus
# 24      네      있다      LG
# 25      네      있다      삼성
# 26      네      없다      한성
# 27      네      없다      LG
# 28      네      없다      삼성
# 29      네      없다      삼성
# 30    아니오      있다      애플
# 31      네      있다      애플
# 32    아니오      있다      LG
# 33      네      없다      LG
# 34      네      있다      LG
# 35      네      없다      애플
# 36      네      없다      삼성
# 37      네      없다      애플
# 38    아니오      있다      LG
# 39      네      없다      LG
# 40      네      없다      애플
# 41      네      있다      LG
# 42      네      있다      LG
# 43      네      있다      LG
# 44      네      있다      LG
# 45      네      있다      LG
# 46      네      있다      LG
# 47      네      없다      LG
# 48      네      없다      LG
# 49      네      없다      LG
# 50      네      없다      LG

# %% [markdown]
# # 1. MBTI E 성향이면 Engel이 높을까?

# %%
def enc(x):
    if x == "I":
        return 1
    else:
        return 0
df['MBTI_IE'] = df['MBTI_IE'].apply(enc)

# %%
def enc(x):
    return x/10000
df['Engel'] = df['Engel'].apply(enc).astype('int')

# %%
# 1. MBTI E 와 Engel의 상관관계

ie = df['MBTI_IE']  # I == 1, E== 0
en = df['Engel']  #

# %%
# 개선점
# 각 박스 위에 데이터 레이블링 해주기

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(18,8))
fig.suptitle("MBTI E 성향이면 Engel이 높을까?", fontsize=30)
_0 = sns.histplot(en, ax=ax[0])
_0.set_title("SAI 멤버들의 식비 분포")

_1 = sns.boxplot(x='MBTI_IE', y='Engel', data=df, ax=ax[1])
_1.set_title("평균 비용 비교")

ticks_2 = ['I', 'E']
_1.set_xticks(range(len(ticks_2)))
_1.set_xticklabels(ticks_2)

for c in df['MBTI_IE'].unique():
    temp = df.loc[df['MBTI_IE']==c, 'Engel']
    temp.mean()
    
group = df.groupby('MBTI_IE').agg('mean')['Engel']
group.index = ['I', 'E']
plt.show()
print(group)
# Out:
# I    7.760000
# E    6.115385
# Name: Engel, dtype: float64

# %%
for m, c in zip(['']orig['MBTI_IE'].unique():
    temp = orig.loc[orig['MBTI_IE']==c, 'Engel']
    print(f"{c}그룹의 평균 소모 비용: \t {temp.mean()}")

# %% [markdown]
# # 2. MBTI E 성향이면 모임 인원 선호도의 상관성은?

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(18,8))
fig.suptitle("2. MBTI E 성향이면 모임 인원 선호도의 상관성은?", fontsize=30)

labels = ['E', 'I']
values = [sum(df['MBTI_IE']==0), sum(df['MBTI_IE']==1)]

pie = ax[0].pie(values, ## 파이차트 출력
       startangle=90, ## 시작점을 90도(degree)로 지정
       counterclock=False, ## 시계 방향으로 그린다.
       autopct=lambda p : '{:.2f}%'.format(p), ## 퍼센티지 출력
       labels = labels
       )
ax[0].set_title("E와 I 비율")


_1 = sns.countplot(x='gathering', hue='MBTI_IE', data=df, ax=ax[1])
_1.set_title("각 그룹의 선호 인원 수")
_1.legend(['E','I'])

plt.show()
print("10명이상을 체크하신 한분이 'E'긴 하지만 한명이라...")
# Out:
# 10명이상을 체크하신 한분이 'E'긴 하지만 한명이라...

# %% [markdown]
# # 3. MBTI J와 벼락치기의 상관관계는?
# - J는 일을 할 때 세부적으로 준비하는 계획형 사람이고, 인식형인 P는 일을 할 때 철저한 계획보다는 융통성 있게 대처하는 사람
# - J는 미리 한다
# - P는 벼락치기 한다.

# %%
# J의 studystyle비율,  P의 studystyle비율을 좌, 우로
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(18,8))
fig.suptitle("3. MBTI J와 벼락치기의 상관관계는?", fontsize=30)

_J = df[df['MBTI_JP']=='J']
_P = df[df['MBTI_JP']=='P']
labels=["벼락치기","미리 공부 해놓기"]

ax[0].pie(_J['studystyle'].value_counts(),
         labels=labels,
         startangle=90,
       counterclock=False,
       autopct=lambda p : '{:.2f}%'.format(p))
ax[0].set_title("J의 벼락치기 비율", fontsize=18)
ax[0].legend()

ax[1].pie(_P['studystyle'].value_counts(),
         labels=labels,
         startangle=90,
       counterclock=False,
       autopct=lambda p : '{:.2f}%'.format(p))
ax[1].set_title("P의 벼락치기 비율", fontsize=18)
ax[1].legend()
plt.show()
print("P의 벼락치기비율이 16%p 더 높았다!...")
print("어? 이게 왜 진짜지...")
# Out:
# P의 벼락치기비율이 16%p 더 높았다!...
# 어? 이게 왜 진짜지...

# %%
# Out:
# 10명이상을 체크하신 한분이 'E'긴 하지만 한명이라...

# %% [markdown]
# # 4. 거북목과 AI공부한 기간+ 프로젝트 횟수

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
temp = df.copy()

def enc_study(x):
    if x == "1년 미만":
        return 0
    elif x == '1년 이상 ~ 2년 미만':
        return 1
    elif x == '2년 이상 ~ 3년 미만':
        return 2
    elif x == "3년 이상":
        return 3
    
def enc_projects(x):
    if x == "없음":
        return 0
    elif x == '1번 이상 ~ 3번 미만':
        return 1
    elif x == '3번 이상 ~ 5번 미만':
        return 2
    elif x == '5번 이상':
        return 3
    
temp['AIstudy'] = temp['AIstudy'].apply(enc_study)
temp['projects'] = temp['projects'].apply(enc_projects)

# %%
# 1. 거북목 유무로 좌우 구분
# 2. factorplot으로 x=학기, y=프로젝트 횟수

temp = df.copy()

def enc_study(x):
    if x == "1년 미만":
        return 0
    elif x == '1년 이상 ~ 2년 미만':
        return 1
    elif x == '2년 이상 ~ 3년 미만':
        return 2
    elif x == "3년 이상":
        return 3
    
def enc_projects(x):
    if x == "없음":
        return 0
    elif x == '1번 이상 ~ 3번 미만':
        return 1
    elif x == '3번 이상 ~ 5번 미만':
        return 2
    elif x == '5번 이상':
        return 3
    
temp['AIstudy'] = temp['AIstudy'].apply(enc_study)
temp['projects'] = temp['projects'].apply(enc_projects)

fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(18,8))
fig.suptitle("4. 거북목과 AI공부한 기간+ 프로젝트 횟수", fontsize=30)

_0 = sns.pointplot(x='AIstudy',  y='projects', data=temp, ax=ax[0], kind='point')
_0.set_title("SAI의 AI공부 기간에 따른 프로젝트 횟수")

_1 = sns.pointplot(x='AIstudy',  y='projects', data=temp, hue='turtle', ax=ax[1], kind='point')
_1.set_title("거북목 유무에 따른 프로젝트 횟수")
_1.legend()

_2 = sns.countplot(x=temp.loc[(temp['AIstudy']==1)& (temp['turtle']=='아니오'),'projects'], ax=ax[2])
_2.set_title('두번째 plot의 AIstudy==1에서 편차가 큰 이유')

plt.show()

# %% [markdown]
# # 5. SAI채널 구독과 Notion 방문횟수

# %%
## 구독 여부와 Notion방문 횟수 countplot
temp = df.copy()
# Out:
#           semester  semester_int       major           otherMajor  MBTI_IE  \
# 0              7학기             7      컴퓨터공학과                 해당없음        0
# 1      8학기 (또는 졸업)             8    호텔관광경영학과  스마트투어리즘 매니지먼트 소프트웨어        0
# 2              7학기             7   전자정보통신공학과                 해당없음        1
# 3              6학기             6        교육학과      글로벌미디어소프트웨어연계전공        1
# 4              3학기             3   데이터사이언스학과            비즈니스애널리틱스        0
# 5              5학기             5      컴퓨터공학과                 해당없음        0
# 6              7학기             7      응용통계학과                 해당없음        1
# 7              3학기             3    스마트기기공학과                 해당없음        1
# 8              7학기             7      컴퓨터공학과                 해당없음        0
# 9           1학기 이하             1      컴퓨터공학과                 해당없음        1
# 10             7학기             7     소프트웨어학과               정보보호학과        0
# 11             6학기             6      컴퓨터공학과                 해당없음        0
# 12             4학기             4      컴퓨터공학과                 해당없음        1
# 13             7학기             7        교육학과                 해당없음        1
# 14             3학기             3     지능기전공학부                 해당없음        1
# 15  8학기 이상 (또는 졸업)             8      컴퓨터공학과                 해당없음        0
# 16             3학기             3     지능기전공학부                 해당없음        0
# 17             6학기             6    스마트기기공학과                 해당없음        1
# 18          1학기 이하             1      인공지능학과                 해당없음        0
# 19             3학기             3        경영학과                 해당없음        1
# 20             5학기             5     소프트웨어학과                 해당없음        1
# 21             5학기             5      컴퓨터공학과                 해당없음        1
# 22             5학기             5      수학통계학부               컴퓨터공학과        0
# 23             3학기             3   전자정보통신공학과                 해당없음        1
# 24  8학기 이상 (또는 졸업)             8        경영학과             디지털콘텐츠학과        0
# 25             5학기             5     소프트웨어학과                 해당없음        1
# 26             5학기             5     소프트웨어학과                 해당없음        1
# 27             3학기             3      응용통계학과                 해당없음        1
# 28             4학기             4      컴퓨터공학과                 해당없음        0
# 29             5학기             5    무인이동체공학과                 해당없음        0
# 30             3학기             3  바이오산업자원공학과                 해당없음        0
# 31             5학기             5   데이터사이언스학과                 해당없음        0
# 32             5학기             5      컴퓨터공학과                 해당없음        1
# 33  8학기 이상 (또는 졸업)             8      컴퓨터공학과                 해당없음        0
# 34             5학기             5      정보보호학과                 해당없음        1
# 35             7학기             7     소프트웨어학과                 해당없음        1
# 36             4학기             4   전자정보통신공학과                 해당없음        0
# 37  8학기 이상 (또는 졸업)             8     지능기전공학부                 해당없음        0
# 38             5학기             5     소프트웨어학과                 해당없음        0
# 39          1학기 이하             1      컴퓨터공학과                 해당없음        1
# 40  8학기 이상 (또는 졸업)             8    무인이동체공학과                 해당없음        0
# 41             3학기             3    스마트기기공학과                 해당없음        1
# 42             7학기             7      컴퓨터공학과                 해당없음        1
# 43             7학기             7      컴퓨터공학과                 해당없음        1
# 44             7학기             7      컴퓨터공학과                 해당없음        1
# 45             7학기             7      컴퓨터공학과                 해당없음        1
# 46             7학기             7      컴퓨터공학과                 해당없음        1
# 47             5학기             5   전자정보통신공학과                 해당없음        0
# 48             5학기             5   전자정보통신공학과                 해당없음        0
# 49             5학기             5   전자정보통신공학과                 해당없음        0
# 50             5학기             5   전자정보통신공학과                 해당없음        0
#
#    MBTI_SN MBTI_TF MBTI_JP      leader gathering      chat_style animal food  \
# 0        N       T       J     절대 안한다.     4명 이상   선톡(내가 먼저 보낸다)    고양이   한식
# 1        S       T       J  없으면 내가 한다.      3~4명  오는톡(오면 답장만 한다)    고양이   한식
# 2        N       T       J  없으면 내가 한다.      3~4명   선톡(내가 먼저 보낸다)    고양이   양식
# 3        S       F       J  시키면 하긴 한다.      3~4명  오는톡(오면 답장만 한다)    고양이   한식
# 4        S       T       J     나서서 한다.    10명 이상   선톡(내가 먼저 보낸다)    고양이   한식
# 5        N       T       J  시키면 하긴 한다.     4명 이상  오는톡(오면 답장만 한다)    강아지   양식
# 6        N       T       J  없으면 내가 한다.      3~4명  오는톡(오면 답장만 한다)    강아지   한식
# 7        S       F       J  없으면 내가 한다.      3~4명  오는톡(오면 답장만 한다)    고양이   일식
# 8        N       T       J     나서서 한다.      3~4명   선톡(내가 먼저 보낸다)    강아지   양식
# 9        S       T       J  시키면 하긴 한다.      3~4명  오는톡(오면 답장만 한다)    고양이   한식
# 10       N       F       P  없으면 내가 한다.      3~4명   선톡(내가 먼저 보낸다)    강아지   한식
# 11       N       T       P     나서서 한다.      3~4명   선톡(내가 먼저 보낸다)    강아지   양식
# 12       S       F       J  없으면 내가 한다.      3~4명   선톡(내가 먼저 보낸다)    고양이   한식
# 13       N       T       J  없으면 내가 한다.      3~4명  오는톡(오면 답장만 한다)    고양이   한식
# 14       S       F       J  시키면 하긴 한다.      3~4명  오는톡(오면 답장만 한다)    고양이   양식
# 15       N       T       J  없으면 내가 한다.      3~4명  오는톡(오면 답장만 한다)    고양이   일식
# 16       S       T       P  없으면 내가 한다.      3~4명  오는톡(오면 답장만 한다)    강아지   양식
# 17       N       F       P  시키면 하긴 한다.      3~4명  오는톡(오면 답장만 한다)    고양이   일식
# 18       N       F       P  없으면 내가 한다.      3~4명  오는톡(오면 답장만 한다)    고양이   한식
# 19       S       F       J  시키면 하긴 한다.      3~4명   선톡(내가 먼저 보낸다)    강아지   양식
# 20       S       F       P  시키면 하긴 한다.      1~2명  오는톡(오면 답장만 한다)    강아지   한식
# 21       N       F       P  없으면 내가 한다.      3~4명   선톡(내가 먼저 보낸다)    고양이   한식
# 22       S       F       P  없으면 내가 한다.      3~4명  오는톡(오면 답장만 한다)    강아지   한식
# 23       N       F       P  없으면 내가 한다.      3~4명  오는톡(오면 답장만 한다)    강아지   양식
# 24       S       T       J     나서서 한다.      3~4명   선톡(내가 먼저 보낸다)    고양이   한식
# 25       S       F       J  시키면 하긴 한다.      3~4명  오는톡(오면 답장만 한다)    강아지   일식
# 26       S       T       P  없으면 내가 한다.      3~4명  오는톡(오면 답장만 한다)    강아지   일식
# 27       S       T       J     절대 안한다.      1~2명  오는톡(오면 답장만 한다)    강아지   양식
# 28       N       T       P     나서서 한다.     4명 이상  오는톡(오면 답장만 한다)    강아지   한식
# 29       S       F       J  없으면 내가 한다.     4명 이상   선톡(내가 먼저 보낸다)    강아지   양식
# 30       N       F       J  없으면 내가 한다.      3~4명  오는톡(오면 답장만 한다)    고양이   일식
# 31       N       F       J  없으면 내가 한다.      3~4명   선톡(내가 먼저 보낸다)    강아지   한식
# 32       N       F       P  시키면 하긴 한다.      1~2명  오는톡(오면 답장만 한다)    강아지   양식
# 33       S       T       J  없으면 내가 한다.     4명 이상   선톡(내가 먼저 보낸다)    강아지   한식
# 34       N       T       P  시키면 하긴 한다.      3~4명   선톡(내가 먼저 보낸다)    고양이   한식
# 35       S       F       P  없으면 내가 한다.      3~4명  오는톡(오면 답장만 한다)    강아지   일식
# 36       N       T       P     나서서 한다.     4명 이상  오는톡(오면 답장만 한다)    고양이   한식
# 37       N       T       P  시키면 하긴 한다.      3~4명  오는톡(오면 답장만 한다)    고양이   양식
# 38       N       T       J     나서서 한다.      3~4명   선톡(내가 먼저 보낸다)    고양이   일식
# 39       S       T       P  없으면 내가 한다.     4명 이상   선톡(내가 먼저 보낸다)    고양이   일식
# 40       N       T       J  없으면 내가 한다.      3~4명  오는톡(오면 답장만 한다)    강아지   한식
# 41       S       F       P  시키면 하긴 한다.      3~4명  오는톡(오면 답장만 한다)    강아지   한식
# 42       N       F       P  없으면 내가 한다.      3~4명  오는톡(오면 답장만 한다)    강아지   일식
# 43       N       F       P  없으면 내가 한다.      3~4명  오는톡(오면 답장만 한다)    강아지   일식
# 44       N       F       P  없으면 내가 한다.      3~4명  오는톡(오면 답장만 한다)    강아지   일식
# 45       N       F       P  없으면 내가 한다.      3~4명  오는톡(오면 답장만 한다)    강아지   일식
# 46       N       F       P  없으면 내가 한다.      3~4명  오는톡(오면 답장만 한다)    강아지   일식
# 47       S       F       J  없으면 내가 한다.      3~4명   선톡(내가 먼저 보낸다)    강아지   한식
# 48       S       F       J  없으면 내가 한다.      3~4명   선톡(내가 먼저 보낸다)    강아지   한식
# 49       S       F       J  없으면 내가 한다.      3~4명   선톡(내가 먼저 보낸다)    강아지   한식
# 50       S       F       J  없으면 내가 한다.      3~4명   선톡(내가 먼저 보낸다)    강아지   한식
#
#    season transportation fastfood_choice cellphone color lifeStyle  getup  \
# 0      여름            지하철              치킨        애플    빨강    아침형 인간      6
# 1      겨울             버스              치킨        삼성    노랑    아침형 인간      8
# 2      겨울            지하철              피자        삼성    빨강   올빼미형 인간     13
# 3      겨울            지하철              피자        삼성    검정   올빼미형 인간     11
# 4      겨울            지하철              피자        삼성    검정   올빼미형 인간     10
# 5      겨울             버스              치킨        삼성    보라   올빼미형 인간      9
# 6      여름            지하철              치킨        삼성    파랑   올빼미형 인간      9
# 7      겨울            지하철              치킨        삼성    검정   올빼미형 인간      9
# 8      여름             버스              치킨        애플    주황   올빼미형 인간      7
# 9      겨울            지하철              치킨        삼성    검정   올빼미형 인간     10
# 10     여름            지하철              치킨        애플    하늘    아침형 인간      9
# 11     겨울             버스              치킨        삼성    초록   올빼미형 인간     11
# 12     겨울             버스              치킨        애플    검정    아침형 인간      8
# 13     겨울            지하철              치킨        애플    파랑   올빼미형 인간     10
# 14     겨울             버스              치킨        애플    분홍   올빼미형 인간     12
# 15     여름             버스              피자        삼성    파랑   올빼미형 인간      8
# 16     겨울             버스              피자        애플    파랑   올빼미형 인간     12
# 17     겨울            지하철              치킨        LG    하늘    아침형 인간      8
# 18     겨울            지하철              치킨        애플    분홍   올빼미형 인간     10
# 19     겨울            지하철              피자        애플    하양   올빼미형 인간     12
# 20     겨울             버스              피자        애플    파랑   올빼미형 인간     10
# 21     겨울            지하철              치킨        삼성    하늘   올빼미형 인간     12
# 22     여름             버스              치킨        애플    하양    아침형 인간      9
# 23     겨울            지하철              치킨        애플    검정   올빼미형 인간     15
# 24     겨울             버스              피자        애플    파랑   올빼미형 인간      8
# 25     겨울             버스              피자        애플    초록   올빼미형 인간      9
# 26     겨울            지하철              치킨        삼성  로즈골드    아침형 인간      6
# 27     겨울             버스              피자        애플    파랑   올빼미형 인간      9
# 28     여름             버스              치킨        삼성    하양   올빼미형 인간      7
# 29     겨울            지하철              치킨        애플    하양    아침형 인간     10
# 30     겨울            지하철              치킨        애플    보라   올빼미형 인간      9
# 31     겨울             버스              피자        애플    하양    아침형 인간      9
# 32     겨울             버스              치킨        애플    하양   올빼미형 인간     10
# 33     겨울            지하철              피자        삼성    초록   올빼미형 인간     11
# 34     여름            지하철              피자        삼성    파랑   올빼미형 인간     11
# 35     겨울            지하철              치킨        애플    노랑   올빼미형 인간     15
# 36     겨울             버스              피자        삼성    검정   올빼미형 인간     11
# 37     겨울             버스              치킨        애플    검정   올빼미형 인간      9
# 38     여름             버스              피자        애플    노랑   올빼미형 인간     12
# 39     겨울            지하철              치킨        애플    하양   올빼미형 인간     12
# 40     겨울             버스              치킨        애플    파랑    아침형 인간      5
# 41     겨울            지하철              치킨        애플    파랑   올빼미형 인간     12
# 42     겨울             버스              피자        애플    파랑   올빼미형 인간     10
# 43     겨울             버스              피자        애플    연두   올빼미형 인간     10
# 44     겨울             버스              피자        애플    초록   올빼미형 인간     10
# 45     겨울             버스              피자        애플    보라   올빼미형 인간     10
# 46     겨울             버스              피자        애플    살구   올빼미형 인간     10
# 47     여름             버스              피자        LG    검정   올빼미형 인간     11
# 48     여름             버스              피자        LG    초록   올빼미형 인간     11
# 49     여름             버스              피자        LG    노랑   올빼미형 인간     11
# 50     여름             버스              피자        LG    주황   올빼미형 인간     11
#
#     Engel       book focus_time     studystyle  workout    QR partTime  \
# 0      10       2~4권  낮 (오전~오후)  꾸준히 미리 공부 해놓기     14.0   네이버     안 한다
# 1       5      1권 이하  밤 (저녁~새벽)           벼락치기      1.0   카카오    하고 있다
# 2       7       2~4권  밤 (저녁~새벽)  꾸준히 미리 공부 해놓기      6.0   카카오     안 한다
# 3       3      1권 이하    때때로 다르다           벼락치기      2.0   카카오    하고 있다
# 4       1  책을 읽지 않는다    때때로 다르다  꾸준히 미리 공부 해놓기      6.0   네이버    하고 있다
# 5      20       2~4권    때때로 다르다  꾸준히 미리 공부 해놓기      4.0   네이버     안 한다
# 6      18      1권 이하  낮 (오전~오후)  꾸준히 미리 공부 해놓기     14.0   네이버     안 한다
# 7       7      1권 이하  밤 (저녁~새벽)  꾸준히 미리 공부 해놓기      1.0   카카오     안 한다
# 8      10      1권 이하    때때로 다르다  꾸준히 미리 공부 해놓기      7.0    토스     안 한다
# 9       7  책을 읽지 않는다  밤 (저녁~새벽)           벼락치기      3.0  수기작성     안 한다
# 10     10      1권 이하    때때로 다르다  꾸준히 미리 공부 해놓기      5.0   카카오    하고 있다
# 11      7  책을 읽지 않는다  밤 (저녁~새벽)           벼락치기      0.0   카카오     안 한다
# 12      5      1권 이하    때때로 다르다           벼락치기      5.0   카카오    하고 있다
# 13      7      1권 이하    때때로 다르다           벼락치기      3.0   카카오     안 한다
# 14      2      1권 이하  밤 (저녁~새벽)           벼락치기      5.0   카카오    하고 있다
# 15     10       2~4권    때때로 다르다  꾸준히 미리 공부 해놓기      6.0   카카오     안 한다
# 16      7      1권 이하  밤 (저녁~새벽)  꾸준히 미리 공부 해놓기      3.0   네이버     안 한다
# 17      7       2~4권    때때로 다르다           벼락치기      2.0   카카오     안 한다
# 18      9      1권 이하  밤 (저녁~새벽)           벼락치기      7.0   카카오     안 한다
# 19      4  책을 읽지 않는다  낮 (오전~오후)           벼락치기      6.0   카카오    하고 있다
# 20      1       2~4권  밤 (저녁~새벽)           벼락치기      9.0   네이버     안 한다
# 21     15      1권 이하    때때로 다르다  꾸준히 미리 공부 해놓기      1.0   네이버    하고 있다
# 22      3      1권 이하  낮 (오전~오후)           벼락치기      4.0   카카오    하고 있다
# 23      5  책을 읽지 않는다  밤 (저녁~새벽)           벼락치기      0.0   카카오    하고 있다
# 24      7       2~4권  밤 (저녁~새벽)           벼락치기      5.0   카카오     안 한다
# 25      2      1권 이하    때때로 다르다  꾸준히 미리 공부 해놓기      0.5   네이버    하고 있다
# 26      5  책을 읽지 않는다  낮 (오전~오후)  꾸준히 미리 공부 해놓기     10.0   카카오     안 한다
# 27      6      1권 이하    때때로 다르다  꾸준히 미리 공부 해놓기      2.0   카카오    하고 있다
# 28      5  책을 읽지 않는다  밤 (저녁~새벽)  꾸준히 미리 공부 해놓기      5.0   네이버     안 한다
# 29      6      1권 이하    때때로 다르다  꾸준히 미리 공부 해놓기      3.0   카카오     안 한다
# 30      7       2~4권  밤 (저녁~새벽)           벼락치기     10.0   카카오     안 한다
# 31     10       2~4권  낮 (오전~오후)  꾸준히 미리 공부 해놓기      3.0   네이버     안 한다
# 32      5      1권 이하    때때로 다르다           벼락치기      0.0   네이버    하고 있다
# 33      5  책을 읽지 않는다  밤 (저녁~새벽)           벼락치기      4.5   카카오     안 한다
# 34      8       2~4권  밤 (저녁~새벽)  꾸준히 미리 공부 해놓기      7.0   카카오     안 한다
# 35      6  책을 읽지 않는다  밤 (저녁~새벽)           벼락치기      0.0   네이버     안 한다
# 36     10      1권 이하  밤 (저녁~새벽)           벼락치기      3.0   네이버    하고 있다
# 37      5      1권 이하    때때로 다르다  꾸준히 미리 공부 해놓기      1.8   카카오     안 한다
# 38      5      1권 이하  밤 (저녁~새벽)           벼락치기      7.0   카카오    하고 있다
# 39      5      1권 이하  밤 (저녁~새벽)           벼락치기      0.5   네이버    하고 있다
# 40      6  책을 읽지 않는다  낮 (오전~오후)  꾸준히 미리 공부 해놓기      0.0   네이버    하고 있다
# 41      9  책을 읽지 않는다  밤 (저녁~새벽)           벼락치기      9.0   네이버     안 한다
# 42      5      1권 이하    때때로 다르다           벼락치기      0.5   카카오     안 한다
# 43      5      1권 이하    때때로 다르다           벼락치기      0.5   카카오     안 한다
# 44      5      1권 이하    때때로 다르다           벼락치기      0.5   카카오     안 한다
# 45      5      1권 이하    때때로 다르다           벼락치기      0.5   카카오     안 한다
# 46      5      1권 이하    때때로 다르다           벼락치기      0.5   카카오     안 한다
# 47      9  책을 읽지 않는다    때때로 다르다           벼락치기      1.5   카카오    하고 있다
# 48      9  책을 읽지 않는다    때때로 다르다           벼락치기      1.5   카카오    하고 있다
# 49      9  책을 읽지 않는다    때때로 다르다           벼락치기      1.5   카카오    하고 있다
# 50      9  책을 읽지 않는다    때때로 다르다           벼락치기      1.5   카카오    하고 있다
#
#           AIstudy  notion subscribe    language       projects kakao_naver  \
# 0   1년 이상 ~ 2년 미만      10        네!      Python          5번 이상         네이버
# 1   1년 이상 ~ 2년 미만       2        네!      Python  1번 이상 ~ 3번 미만         카카오
# 2   1년 이상 ~ 2년 미만       5        네!      MATLAB          5번 이상         네이버
# 3   1년 이상 ~ 2년 미만       3        네!      Python  1번 이상 ~ 3번 미만         네이버
# 4           1년 미만       3        네!      Python  1번 이상 ~ 3번 미만         카카오
# 5   2년 이상 ~ 3년 미만       5        네!      Python          5번 이상         카카오
# 6   1년 이상 ~ 2년 미만       1        네!      Python  3번 이상 ~ 5번 미만         카카오
# 7           1년 미만       1        네!      Python  1번 이상 ~ 3번 미만         카카오
# 8   1년 이상 ~ 2년 미만       5        네!  JavaScript          5번 이상         네이버
# 9           1년 미만       2        네!      Python             없음         카카오
# 10          1년 미만       3        네!  JavaScript          5번 이상         카카오
# 11          1년 미만       0        네!      Python  1번 이상 ~ 3번 미만         카카오
# 12          1년 미만       2       아니오           C             없음         카카오
# 13          1년 미만       3       아니오      Python  3번 이상 ~ 5번 미만         네이버
# 14          1년 미만       2        네!           C             없음         카카오
# 15          3년 이상       0        네!      Python          5번 이상         카카오
# 16          1년 미만       3        네!           C             없음         카카오
# 17  1년 이상 ~ 2년 미만       0       아니오      Python  3번 이상 ~ 5번 미만         카카오
# 18          1년 미만       1        네!      Python             없음         카카오
# 19  1년 이상 ~ 2년 미만       5        네!      Python             없음         카카오
# 20          1년 미만       1        네!           C  1번 이상 ~ 3번 미만         카카오
# 21          1년 미만       0        네!        JAVA  1번 이상 ~ 3번 미만         카카오
# 22          1년 미만       3        네!           C             없음         카카오
# 23          1년 미만       2        네!      Python  1번 이상 ~ 3번 미만         카카오
# 24  2년 이상 ~ 3년 미만       0        네!      Python  3번 이상 ~ 5번 미만         카카오
# 25          1년 미만       0        네!           C  1번 이상 ~ 3번 미만         카카오
# 26          1년 미만       1        네!      Python  1번 이상 ~ 3번 미만         카카오
# 27          1년 미만       2       아니오      Python             없음         카카오
# 28  1년 이상 ~ 2년 미만       0       아니오      Python  1번 이상 ~ 3번 미만         카카오
# 29  1년 이상 ~ 2년 미만       0        네!         C++  3번 이상 ~ 5번 미만         네이버
# 30  2년 이상 ~ 3년 미만       5        네!        JAVA          5번 이상         카카오
# 31          1년 미만       2        네!      Python          5번 이상         카카오
# 32          1년 미만       0       아니오           C  1번 이상 ~ 3번 미만         카카오
# 33          1년 미만       0        네!  JavaScript             없음         네이버
# 34          1년 미만       3        네!           C          5번 이상         카카오
# 35          1년 미만       0        네!  JavaScript  3번 이상 ~ 5번 미만         카카오
# 36          1년 미만       2        네!           C             없음         카카오
# 37          3년 이상       0        네!      Python          5번 이상         네이버
# 38          1년 미만       2        네!           C  3번 이상 ~ 5번 미만         네이버
# 39          1년 미만       0        네!           C             없음         네이버
# 40  1년 이상 ~ 2년 미만       0        네!      Python          5번 이상         카카오
# 41          1년 미만       0        네!           C             없음         네이버
# 42          1년 미만       0        네!           C  3번 이상 ~ 5번 미만         네이버
# 43          1년 미만       0        네!           C  3번 이상 ~ 5번 미만         네이버
# 44          1년 미만       0        네!           C  3번 이상 ~ 5번 미만         네이버
# 45          1년 미만       0        네!           C  3번 이상 ~ 5번 미만         네이버
# 46          1년 미만       0        네!           C  3번 이상 ~ 5번 미만         네이버
# 47          1년 미만       2        네!      Python             없음         카카오
# 48          1년 미만       2        네!      Python             없음         카카오
# 49          1년 미만       2        네!      Python             없음         카카오
# 50          1년 미만       2        네!      Python             없음         카카오
#
#    turtle sticker  laptop
# 0       네      있다      한성
# 1       네      없다     Msi
# 2     아니오      없다      삼성
# 3     아니오      없다      삼성
# 4     아니오      있다      LG
# 5     아니오      있다      애플
# 6       네      없다    asus
# 7     아니오      있다      LG
# 8     아니오      있다      애플
# 9       네      없다      삼성
# 10      네      있다      애플
# 11      네      있다   기가바이트
# 12      네      없다      애플
# 13      네      없다      LG
# 14      네      있다      삼성
# 15      네      없다  Lenova
# 16      네      없다    asus
# 17      네      없다      애플
# 18      네      없다      애플
# 19    아니오      없다      삼성
# 20      네      있다      삼성
# 21      네      있다      삼성
# 22      네      있다      삼성
# 23    아니오      없다    asus
# 24      네      있다      LG
# 25      네      있다      삼성
# 26      네      없다      한성
# 27      네      없다      LG
# 28      네      없다      삼성
# 29      네      없다      삼성
# 30    아니오      있다      애플
# 31      네      있다      애플
# 32    아니오      있다      LG
# 33      네      없다      LG
# 34      네      있다      LG
# 35      네      없다      애플
# 36      네      없다      삼성
# 37      네      없다      애플
# 38    아니오      있다      LG
# 39      네      없다      LG
# 40      네      없다      애플
# 41      네      있다      LG
# 42      네      있다      LG
# 43      네      있다      LG
# 44      네      있다      LG
# 45      네      있다      LG
# 46      네      있다      LG
# 47      네      없다      LG
# 48      네      없다      LG
# 49      네      없다      LG
# 50      네      없다      LG

# %% [markdown]
# # 6. 색과 카카오_네이버의 관계?

# %% [markdown]
# # 7. 이수학기 와 프로젝트 진행횟수?
